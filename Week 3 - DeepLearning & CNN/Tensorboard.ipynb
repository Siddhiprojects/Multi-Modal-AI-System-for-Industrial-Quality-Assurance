# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
(X_train, y_train) , (X_test, y_test) = keras.datasets.mnist.load_data()

# %%
plt.matshow(X_train[0])

# %%
y_train[0]
# Out:
# np.uint8(5)

# %%
X_train = X_train / 255
X_test = X_test / 255
X_train_flattened = X_train.reshape(len(X_train), 28*28)
X_test_flattened = X_test.reshape(len(X_test), 28*28)

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(100, activation='relu'),
    keras.layers.Dense(10, activation='sigmoid')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

tb_callback = tf.keras.callbacks.TensorBoard(log_dir="logs/", histogram_freq=1)

model.fit(X_train, y_train, epochs=5, callbacks=[tb_callback])
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9207 - loss: 0.2751
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9639 - loss: 0.1238
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9737 - loss: 0.0866
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9791 - loss: 0.0666
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9841 - loss: 0.0519

# %%
pip install tensorboard
# Out:
# Collecting tensorboard
#   Downloading tensorboard-2.20.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: absl-py>=0.4 in c:\users\admin\anaconda3\lib\site-packages (from tensorboard) (2.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\admin\anaconda3\lib\site-packages (from tensorboard) (1.81.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\admin\anaconda3\lib\site-packages (from tensorboard) (3.8)
# Requirement already satisfied: numpy>=1.12.0 in c:\users\admin\anaconda3\lib\site-packages (from tensorboard) (2.3.5)
# Requirement already satisfied: packaging in c:\users\admin\anaconda3\lib\site-packages (from tensorboard) (25.0)
# Requirement already satisfied: pillow in c:\users\admin\anaconda3\lib\site-packages (from tensorboard) (12.0.0)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in c:\users\admin\anaconda3\lib\site-packages (from tensorboard) (7.35.1)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\admin\anaconda3\lib\site-packages (from tensorboard) (80.9.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard)
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\admin\anaconda3\lib\site-packages (from tensorboard) (3.1.3)
# Requirement already satisfied: typing-extensions~=4.12 in c:\users\admin\anaconda3\lib\site-packages (from grpcio>=1.48.2->tensorboard) (4.15.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\admin\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard) (3.0.2)
# Downloading tensorboard-2.20.0-py3-none-any.whl (5.5 MB)
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    - -------------------------------------- 0.3/5.5 MB ? eta -:--:--
#    --------- ------------------------------ 1.3/5.5 MB 4.3 MB/s eta 0:00:01
#    ----------------- ---------------------- 2.4/5.5 MB 5.1 MB/s eta 0:00:01
#    -------------------------- ------------- 3.7/5.5 MB 5.3 MB/s eta 0:00:01
#    -------------------------------- ------- 4.5/5.5 MB 5.4 MB/s eta 0:00:01
#    ---------------------------------------- 5.5/5.5 MB 5.1 MB/s  0:00:01
# Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Installing collected packages: tensorboard-data-server, tensorboard
#
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    -------------------- ------------------- 1/2 [tensorboard]
#    ---------------------------------------- 2/2 [tensorboard]
#
# Successfully installed tensorboard-2.20.0 tensorboard-data-server-0.7.2
# Note: you may need to restart the kernel to use updated packages.

# %%
model.get_weights()
