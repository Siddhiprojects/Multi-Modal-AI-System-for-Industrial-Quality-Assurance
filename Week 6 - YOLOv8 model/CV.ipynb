# %%
pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 31.2 MB/s eta 0:00:00
# ...

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU")
# Out:
# True
# Tesla T4

# %%
from google.colab import files
uploaded = files.upload()  # select your zip from your computer
# Out:
#      <input type="file" id="files-572e2c86-51d3-448e-8932-20c239bdece4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-572e2c86-51d3-448e-8932-20c239bdece4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile

with zipfile.ZipFile('archive.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/archive')

# %%
import os
print(len(os.listdir("/content/archive/train/train/images")))
# Out:
# 1770

# %%
from ultralytics import YOLO

models = [
    "yolov8n.pt",
    "yolov8s.pt",
    "yolov8m.pt",
    "yolov8l.pt"
]

for model_name in models:
    print(f"\nTraining {model_name}...\n")

    model = YOLO(model_name)

    model.train(
        data="/content/archive/data.yaml",
        epochs=2,
        imgsz=640,
        batch=16,
        project="YOLO_Experiments",
        name=model_name.replace(".pt", "")
    )
# Out:
# Training yolov8n.pt...
#
# ...
# Ultralytics 8.4.87 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO("runs/detect/YOLO_Experiments/yolov8n/weights/best.pt")
metrics = model.val(data="/content/archive/data.yaml")

print("Precision :", metrics.box.mp)
print("Recall    :", metrics.box.mr)
print("mAP@50    :", metrics.box.map50)
print("mAP@50-95 :", metrics.box.map)
# Out:
# Ultralytics 8.4.87 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 3,006,818 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 929.6±292.5 MB/s, size: 15.4 KB)
# val: Scanning /content/archive/valid/valid/labels.cache... 30 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 30/30 9.0Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.8it/s 1.1s
#                    all         30         64      0.582      0.633      0.638      0.318
#                crazing          5          8      0.331      0.375      0.262      0.114
#              inclusion          5         15      0.529        0.8      0.714      0.331
#                patches          5         17      0.653      0.995      0.921      0.518
#         pitted_surface          5          8      0.933        0.5      0.804      0.503
# ...

# %%
from ultralytics import YOLO

model = YOLO("runs/detect/YOLO_Experiments/yolov8s/weights/best.pt")
metrics = model.val(data="/content/archive/data.yaml")

print("Precision :", metrics.box.mp)
print("Recall    :", metrics.box.mr)
print("mAP@50    :", metrics.box.map50)
print("mAP@50-95 :", metrics.box.map)
# Out:
# Ultralytics 8.4.87 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 11,127,906 parameters, 0 gradients, 28.4 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 636.8±264.2 MB/s, size: 16.6 KB)
# val: Scanning /content/archive/valid/valid/labels.cache... 30 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 30/30 9.0Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.6s
#                    all         30         64      0.713      0.581      0.665      0.328
#                crazing          5          8          1          0      0.572      0.194
#              inclusion          5         15      0.628      0.667      0.562      0.233
#                patches          5         17      0.592      0.938      0.899      0.548
#         pitted_surface          5          8      0.703        0.5      0.661      0.445
# ...

# %%
from ultralytics import YOLO

model = YOLO("runs/detect/YOLO_Experiments/yolov8m/weights/best.pt")
metrics = model.val(data="/content/archive/data.yaml")

print("Precision :", metrics.box.mp)
print("Recall    :", metrics.box.mr)
print("mAP@50    :", metrics.box.map50)
print("mAP@50-95 :", metrics.box.map)
# Out:
# Ultralytics 8.4.87 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 93 layers, 25,843,234 parameters, 0 gradients, 78.7 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 969.9±317.8 MB/s, size: 18.0 KB)
# val: Scanning /content/archive/valid/valid/labels.cache... 30 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 30/30 12.6Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.6s
#                    all         30         64      0.786      0.529      0.646      0.323
#                crazing          5          8          1          0      0.339     0.0829
#              inclusion          5         15      0.637      0.704      0.603      0.295
#                patches          5         17      0.719      0.882      0.871      0.493
#         pitted_surface          5          8          1      0.369      0.553      0.417
# ...

# %%
from ultralytics import YOLO

model = YOLO("runs/detect/YOLO_Experiments/yolov8l/weights/best.pt")
metrics = model.val(data="/content/archive/data.yaml")

print("Precision :", metrics.box.mp)
print("Recall    :", metrics.box.mr)
print("mAP@50    :", metrics.box.map50)
print("mAP@50-95 :", metrics.box.map)
# Out:
# Ultralytics 8.4.87 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 113 layers, 43,611,234 parameters, 0 gradients, 164.8 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 796.4±401.0 MB/s, size: 12.1 KB)
# val: Scanning /content/archive/valid/valid/labels.cache... 30 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 30/30 6.6Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.1s/it 2.2s
#                    all         30         64      0.345      0.435      0.178     0.0834
#                crazing          5          8      0.448      0.375      0.411       0.17
#              inclusion          5         15     0.0096      0.533     0.0075    0.00389
#                patches          5         17      0.243      0.882      0.342       0.14
#         pitted_surface          5          8      0.367      0.375      0.292      0.181
# ...

# %% [markdown]
# The best model is therefore YoloV8m as it has the highest accuracy will use this for training the model with 100 epochs.
